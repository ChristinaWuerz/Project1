# %%
# Dependencies
import requests
import json
import pandas as pd
import gmaps
# Google developer API key
from config import gkey
# gmaps.configure(api_key=gkey)

# %%
# Target county
target_county = "dallas county"

# Build the endpoint URL
target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_county, gkey)

# %%
geo_data = requests.get(target_url).json()

# Print the json
print(geo_data)
# Out:
# {'results': [{'address_components': [{'long_name': 'Dallas County', 'short_name': 'Dallas County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Dallas County, TX, USA', 'geometry': {'bounds': {'northeast': {'lat': 32.9893279, 'lng': -96.5168659}, 'southwest': {'lat': 32.5452141, 'lng': -97.03838499999999}}, 'location': {'lat': 32.8024682, 'lng': -96.83509989999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 32.9893279, 'lng': -96.5168659}, 'southwest': {'lat': 32.5452141, 'lng': -97.03838499999999}}}, 'place_id': 'ChIJgUO9Ukq_ToYRh9ndnDaZsUc', 'types': ['administrative_area_level_2', 'political']}], 'status': 'OK'}

# %%
# Print the json (pretty printed)
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Dallas County",
#                     "short_name": "Dallas County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Dallas County, TX, USA",
# ...

# %%
target_coordinates = "32.8024682,-96.83509989999999"
target_radius = 40233.6
target_search = "urgent care"

uc_url = (f'https://maps.googleapis.com/maps/api/place/nearbysearch/json?'
    'location={0}&radius={1}&keyword={3}&key={3}').format(target_coordinates, target_radius, target_search, gkey)

#clinic_info = requests.get(uc_url).json()
#print(clinic_info)

# %%
#dont include percentage in seperating keywords
#target_coordinates = "32.8024682,-96.83509989999999"
#target_radius = 40233.6
#target_search = "urgent care"
#params = {
   # "location": target_coordinates,
    #"keyword": target_search,
    #"radius": target_radius,
   # "key": gkey}
#uc_url="https://maps.googleapis.com/maps/api/place/nearbysearch/json?"
uc_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=32.8024682,-96.83509989999999&radius=40233.6&keyword=urgentcare&key=AIzaSyCwxBI6kg_KgCQ_ctdlYP25m-6Q226H2WI'
clinic_info = requests.get(uc_url).json()
# Print the json (pretty printed)
print(json.dumps(clinic_info, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCIQEAAFW90AKOa44daTyJ297Gr2WbK-c5ypoKUKnEvGcF5hjPZwsC91WJBv_5x7UirILgXXKBxYbRDjG1AULn9ML8sqhYfn_o0gqCwIvzXR-Ov70676giQd4UfNg9cTywbCYa9ai0fVmYQF2cXFFydsFbhx8kf-NoScH1YbIlxhNqYi8-U9oZ4Z59MtJA2edoIvEEwL4VYKyxWfyDUYP3dQTxnEEcEu2sb6lN3aKlANjXdSZ6b1iaPQRA5vpymwaNWDupjJgdFBLVvmb2cA6t1EDksCwPykw0hw3tahNF1q_vpp8XJ_VP7t6cRhUalaOSAdRikfVOH1m0bEVyOPV0JiYL9hCK8HL0qD13jSWcGUKoXOMeTZysjZdZ5_V7KVmNIZKXCYVsolxS28ZkQOXh0fCY2qISEPphwe8KzTkasvOY4xSf2q8aFJ6p27IfP-RLRcnAvTqt5X5ri57b",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 32.6568196,
#                     "lng": -96.75068639999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.65817712989272,
#                         "lng": -96.74924897010729
#                     },
#                     "southwest": {
# ...

# %%
urgent_care=[]
clinics = clinic_info['results']
for c in clinics:
    name = c['name']
    lat = c['geometry']['location']['lat']
    lng=c['geometry']['location']['lng']
    address = c['vicinity']
    urgent_care.append({"Urgent_Care": name,
                      "Lat": lat,
                        "Lng":lng,
                       "Address": address})
print(urgent_care)
# Out:
# [{'Urgent_Care': 'UrgentCare Travel Clinic', 'Lat': 32.6568196, 'Lng': -96.75068639999999, 'Address': '7383 Bonnie View Rd, Dallas'}]
# [{'Urgent_Care': 'UrgentCare Travel Clinic', 'Lat': 32.6568196, 'Lng': -96.75068639999999, 'Address': '7383 Bonnie View Rd, Dallas'}, {'Urgent_Care': 'CareNow Urgent Care - Las Colinas - MacArthur', 'Lat': 32.90753580000001, 'Lng': -96.9582614, 'Address': '7400 N MacArthur Blvd, Irving'}]
# [{'Urgent_Care': 'UrgentCare Travel Clinic', 'Lat': 32.6568196, 'Lng': -96.75068639999999, 'Address': '7383 Bonnie View Rd, Dallas'}, {'Urgent_Care': 'CareNow Urgent Care - Las Colinas - MacArthur', 'Lat': 32.90753580000001, 'Lng': -96.9582614, 'Address': '7400 N MacArthur Blvd, Irving'}, {'Urgent_Care': 'Integra Urgent Care - Grand Prairie', 'Lat': 32.6779586, 'Lng': -97.0089385, 'Address': '3950 S Carrier Pkwy Ste 110, Grand Prairie'}]
# ...

# %%
clinicOne_df = pd.DataFrame(urgent_care)
clinicOne_df = clinicOne_df[["Urgent_Care","Address","Lat","Lng"]]


clinicOne=clinicOne_df.to_csv("Resources/ClinicList.csv", index=False, header=True)
clinicOne="Resources/ClinicList.csv"
clinicOne_df2=pd.read_csv(clinicOne)
clinicOne_df2.head()
# Out:
#                                      Urgent_Care  \
# 0                       UrgentCare Travel Clinic
# 1  CareNow Urgent Care - Las Colinas - MacArthur
# 2            Integra Urgent Care - Grand Prairie
# 3                     CityDoc Urgent Care Uptown
# 4              Integra Urgent Care - Las Colinas
#
#                                       Address        Lat        Lng
# 0                 7383 Bonnie View Rd, Dallas  32.656820 -96.750686
# 1               7400 N MacArthur Blvd, Irving  32.907536 -96.958261
# 2  3950 S Carrier Pkwy Ste 110, Grand Prairie  32.677959 -97.008938
# 3                   2909 McKinney Ave, Dallas  32.799884 -96.801149
# 4       7447 N MacArthur Blvd Ste 190, Irving  32.907823 -96.960527

# %%
next_url_one=('https://maps.googleapis.com/maps/api/place/nearbysearch/json?pagetoken=CrQCIQEAALiZsJGbdMvXxlbsv-ggDzNhhuV_sXpakTlMAgB1TIE0oCa-ilpbMh8O_Zhw5iUQF8yb7voRs-s5q4wWFeVtjhPNvxp0In7Gy6qE5295DbOMVLJR6hHYTxT9UfXfTSCtBERT-V7QD7u9jwR5cwySGaq7IKw4K8R4Rqu20DNyO_HiklXYF-TLf9ScNS3FJ_Wk-JTmPqFPz-IB3paCO_cLQnkuo1VsNhTlNNyNA083jJd5V92krLobhZTyDmtP3b9cJdATV8OVv4mOx6F2S8V-nZZntOys7QBmyVTNbiGHUBGPUpZ73C85K1R75s7cSTObzMyl6eUa9kMTlkS7WFM5n0PgCldb9ARKnK8zLEObG68_aeIzvRbGzf-Qlvpz7QXdq0Rh8E1kPx8y13ChmI23VeYSEBbNRFB7vd2HaV6bwaHuta0aFLDc-MkppDAUy335sjnN0hLt5Hvu&key=AIzaSyCwxBI6kg_KgCQ_ctdlYP25m-6Q226H2WI')
#next_token1 = response['next_url_one']
next_token1=requests.get(next_url_one).json()
# Print the json (pretty printed)
print(json.dumps(next_token1, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CtQDwQEAAEmLxlOvBeiellxAbkaM0XElirH47Xgi5N0GysCFfzrUDawT51tNwGPFjY_dlKkXOpY7BQbMjxVdgEvXgAFHzCLbMFJ4-T90Pin9KRJSTy24HlRrUDulmAWGwjw_VL_AnXCRjaGL0Oa_49WnFpLUZYsHaW2oJpfnjnunnUGpf4NaTHA9n7i_Rf0b9RZkwLSQsdpBbZLamMlv01yTnEIRhj7nzR9uYw4JTIMY8NOd4qWPx7s7vIHZtT8o1t3oLKkP5CZblklaR0srO9FXDuIuLjI2mZnKJrv--B4hPcYMqtXk98TJPjV0337HbevGUQna-LvQ8u8j5vVDXmNYgwfDqXgNra_1GYEm4oJGpTONMiD7YGusxyZJmDi2_pgfESusxSdwNqMit4lLLhtLc_N4wne69CkzpkJninvroBRiDE9m_BXQWXOmTbdBvaRVHtzsYu32q-L1GxTdbJJJZjKsSHZ9x4nJgBdplVCrKzoJ-_BzUOh_fk8LTZDJ2lFf8pVuCQq-H993mEj4JGN2c-mkhsUgLdOw74RDYZhuUZZRRMwd4l8DqcJrB2lnUDJxdUqnaXPhdi97Zetf3ppFlXCfL_ViesSEFcugONBX8OrvFNE1EhA4F0H1KsYT7Q6JYCAqdOlTGhREB7ZhWZR07NTPQSsbET52kiQIbA",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 32.90753580000001,
#                     "lng": -96.9582614
#                 },
#                 "viewport": {
# ...

# %%
urgent_care2=[]

clinics_two = next_token1['results']
for c in clinics_two:
    name = c['name']
    lat = c['geometry']['location']['lat']
    lng=c['geometry']['location']['lng']
    address = c['vicinity']
    urgent_care2.append({"Urgent_Care": name,
                      "Lat": lat,
                         "Lng":lng,
                      "Address": address})
    
    
    
print(urgent_care2)
# Out:
# [{'Urgent_Care': 'CareNow Urgent Care - Las Colinas - MacArthur', 'Lat': 32.90753580000001, 'Lng': -96.9582614, 'Address': '7400 N MacArthur Blvd, Irving'}, {'Urgent_Care': 'Integra Urgent Care - Grand Prairie', 'Lat': 32.6779586, 'Lng': -97.0089385, 'Address': '3950 S Carrier Pkwy Ste 110, Grand Prairie'}, {'Urgent_Care': 'Urgent Care of Texas & Expecare Family Care @ Arlington', 'Lat': 32.6408484, 'Lng': -97.13362409999999, 'Address': '6407 S Cooper St #117, Arlington'}, {'Urgent_Care': 'CareNow Urgent Care - Uptown', 'Lat': 32.794725, 'Lng': -96.802021, 'Address': '2404 McKinney Ave, Dallas'}, {'Urgent_Care': 'Integra Urgent Care - Las Colinas', 'Lat': 32.9078226, 'Lng': -96.96052730000001, 'Address': '7447 N MacArthur Blvd Ste 190, Irving'}, {'Urgent_Care': 'CareNow Urgent Care – Greenville', 'Lat': 32.8468785, 'Lng': -96.76969439999999, 'Address': '4844 Greenville Ave, Dallas'}, {'Urgent_Care': 'CareNow Urgent Care - Cedar Hill', 'Lat': 32.5937493, 'Lng': -96.9434082, 'Address':
# ...

# %%
clinicTwo_df = pd.DataFrame(urgent_care2)
clinicTwo_df = clinicTwo_df[["Urgent_Care","Address","Lat","Lng"]]

clinicTwo=clinicTwo_df.to_csv("Resources/ClinicList2.csv", index=False, header=True)
clinicTwo="Resources/ClinicList2.csv"
clinicTwo_df2=pd.read_csv(clinicTwo)

clinicTwo_df2.head()
# Out:
#                                          Urgent_Care  \
# 0      CareNow Urgent Care - Las Colinas - MacArthur
# 1                Integra Urgent Care - Grand Prairie
# 2  Urgent Care of Texas & Expecare Family Care @ ...
# 3                       CareNow Urgent Care - Uptown
# 4                  Integra Urgent Care - Las Colinas
#
#                                       Address        Lat        Lng
# 0               7400 N MacArthur Blvd, Irving  32.907536 -96.958261
# 1  3950 S Carrier Pkwy Ste 110, Grand Prairie  32.677959 -97.008938
# 2            6407 S Cooper St #117, Arlington  32.640848 -97.133624
# 3                   2404 McKinney Ave, Dallas  32.794725 -96.802021
# 4       7447 N MacArthur Blvd Ste 190, Irving  32.907823 -96.960527

# %%
next_url_two=('https://maps.googleapis.com/maps/api/place/nearbysearch/json?pagetoken=CtQDwQEAAI6KeTHso0wjJQJ5enf0BDPki63uEjVusi_V_t7po0t5B1YWMIeTVf2etdz0x9vyvmWn2zfE7yKxIVRv-wJBUa_vYDBk1GBXyWZAIe6Ffn2q6DOQZn40uWuxOpkN9CcYuHB5tM_-7ebYFr_6AR6J6ncqZmMTLBeanPuZPoBKJC-cTzlImMagmi9Ia0oItIuoxsTsMzKgA3eq88g8ImOA88UF17MDIHhrSrjoeidc7Bc0ZzFDe8897XRHzGtSBXdOghdPKpanzBSmmkQCrJ624H_DF-TZp4MlneGhVrPawMiZJ6Zhag8_nZ-53AfRSv8wu7_56ABwshTmK7GbOUGmHTdZ3FNpxpyMEjZ0r8bzdPB-3QGUtGXwVIm0ICs3Gzr8PUDn8sdNpvCuVhf5Yuq1LQ96RReA25w6PS59Yd2E2ny37PywhOxplgpoQCK1eTge8uybeVhZg1zNa7L3DyXekU-4Fzp12Qwyd6_gcz4j1MogVG3yFGwWXG1bTHqyT6I-1TJF8JCNFJIJtv6JI2LC4zE-VC45xaKkbYGRQYWqtFtMMjaET3JTBIlcyaprrrokeB2w0iM_RUfFkXLJ_UmpW20G8t-mopODTTEIXS2vTb6IEhBTw8UBsrzPjEST9fhX8eCNGhQAgIg95JCxDGxeWhfL1NhOUmlCTg&key=AIzaSyCwxBI6kg_KgCQ_ctdlYP25m-6Q226H2WI')
next_token2=requests.get(next_url_two).json()

# Print the json (pretty printed)
print(json.dumps(next_token2, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 32.9078226,
#                     "lng": -96.96052730000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.90937387989272,
#                         "lng": -96.95910192010727
#                     },
#                     "southwest": {
#                         "lat": 32.90667422010728,
#                         "lng": -96.96180157989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "d1a41909284413e33159f369010f527cf6a14d3f",
#             "name": "Integra Urgent Care - Las Colinas",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
# ...

# %%
urgent_care3=[]
clinics_three = next_token2['results']
for c in clinics_three:
    name = c['name']
    lat = c['geometry']['location']['lat']
    lng=c['geometry']['location']['lng']
    address = c['vicinity']

                      
    urgent_care3.append({"Urgent_Care": name,
                      "Lat": lat,
                         "Lng":lng,
                      "Address": address})
    print(urgent_care3)
# Out:
# [{'Urgent_Care': 'Integra Urgent Care - Las Colinas', 'Lat': 32.9078226, 'Lng': -96.96052730000001, 'Address': '7447 N MacArthur Blvd Ste 190, Irving'}]
# [{'Urgent_Care': 'Integra Urgent Care - Las Colinas', 'Lat': 32.9078226, 'Lng': -96.96052730000001, 'Address': '7447 N MacArthur Blvd Ste 190, Irving'}, {'Urgent_Care': 'Urgent Care of Texas & Expecare Family Care @ Arlington', 'Lat': 32.6408484, 'Lng': -97.13362409999999, 'Address': '6407 S Cooper St #117, Arlington'}]
# [{'Urgent_Care': 'Integra Urgent Care - Las Colinas', 'Lat': 32.9078226, 'Lng': -96.96052730000001, 'Address': '7447 N MacArthur Blvd Ste 190, Irving'}, {'Urgent_Care': 'Urgent Care of Texas & Expecare Family Care @ Arlington', 'Lat': 32.6408484, 'Lng': -97.13362409999999, 'Address': '6407 S Cooper St #117, Arlington'}, {'Urgent_Care': 'CareNow Urgent Care – Greenville', 'Lat': 32.8468785, 'Lng': -96.76969439999999, 'Address': '4844 Greenville Ave, Dallas'}]
# ...

# %%
clinicThree_df = pd.DataFrame(urgent_care3)
clinicThree_df = clinicThree_df[["Urgent_Care","Address","Lat","Lng"]]

# %%
#combined df, now save as csv, ignored index
combineClinic=pd.concat([clinicOne_df,clinicTwo_df,clinicThree_df],ignore_index=True)
combineClinic
# Out:
#                                           Urgent_Care  \
# 0                            UrgentCare Travel Clinic
# 1       CareNow Urgent Care - Las Colinas - MacArthur
# 2                 Integra Urgent Care - Grand Prairie
# 3                          CityDoc Urgent Care Uptown
# 4                   Integra Urgent Care - Las Colinas
# 5                        CareNow Urgent Care - Uptown
# 6   Urgent Care of Texas & Expecare Family Care @ ...
# 7                   FastPass Urgent Care - Carrollton
# 8                    CareNow Urgent Care – Greenville
# 9                      Urgent Care of Texas @ Coppell
# 10                   CareNow Urgent Care - Cedar Hill
# 11                 CareNow Urgent Care - North Dallas
# 12                             MedExpress Urgent Care
# 13                            Legacy ER & Urgent Care
# 14             CareNow Urgent Care - I-20 & Wheatland
# 15                        Cook Children's Urgent Care
# ...

# %%
#saves Master List as csv
combineClinic_csv=combineClinic.to_csv("Resources/ClinicMasterComplete.csv", index=False, header=True)
combineClinic_csv="Resources/ClinicMasterCmplete.csv"

# %%
# Configure gmaps with API key
gmaps.configure(gkey)

# %%
places = combineClinic[["Lat","Lng"]]


# HINT: be sure to handle NaN values
care_name = combineClinic["Urgent_Care"]

# %%
clinic_layer = gmaps.symbol_layer(
    places, fill_color='blue',
    stroke_color='blue', scale=3
)
